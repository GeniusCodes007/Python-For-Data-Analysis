# %%
import numpy as np

# %%
num_array=np.array([1,2,3,4,5])

# %%
pos_array=np.array(["Data", "Software", "Desktop", "Web", "Digital"])

# %%
base=2000

# %%
salary=num_array*base
salary
# Out:
# array([ 2000,  4000,  6000,  8000, 10000])

# %%
np.mean(salary)
# Out:
# np.float64(6000.0)

# %%
# Runs mean in a situation where there may be incomplete data
np.nanmean(salary)
# Out:
# np.float64(6000.0)
