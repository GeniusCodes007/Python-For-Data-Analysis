# %%
print("Bee")
# Out:
# Bee

# %%
import random 

num_list=[random.randint(0, 10) for _ in range(5)]
print(num_list)
# Out:
# [4, 4, 2, 9, 0]

# %%
num_list.append(3)
print(num_list)
# Out:
# [4, 4, 2, 9, 0, 3]
