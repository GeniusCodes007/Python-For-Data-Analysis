# %%
"Matplotlib Loading!!!"
# Out:
# 'Matplotlib Loading!!!'

# %%
"Matplotlib About To Start, Just Testing"
# Out:
# 'Matplotlib About To Start, Just Testing'

# %%
import pandas as pd
data=pd.read_csv("../../csv_files/LoanData.csv")
data
# Out:
#        Status Credit.Grade  Amount  Age  Borrower.Rate  Debt.To.Income.Ratio
# 0     Current            C    5000    4         0.1500                 0.040
# 1     Current           HR    1900    6         0.2650                 0.020
# 2     Current           HR    1000    3         0.1500                 0.020
# 3     Current           HR    1000    5         0.2900                 0.020
# 4     Current           AA    2550    8         0.0795                 0.033
# ...       ...          ...     ...  ...            ...                   ...
# 5606  Current            A   25000    4         0.1700             16270.350
# 5607  Current            C    3000    1         0.1445             17901.440
# 5608  Current            C    5500    6         0.1775             29713.690
# 5609  Current            D   20000    1         0.1700             33313.930
# 5610  Current            B   20000    2         0.1605             51280.070
#
# [5611 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
values_x=np.arange(0,5,0.1)
values_y=np.sin(values_x)
plt.plot(values_x, values_y)
