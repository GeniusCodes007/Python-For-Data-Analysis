# %%
"Matplotlib Loading!!!"
# Out:
# 'Matplotlib Loading!!!'

# %%
"Matplotlib About To Start, Just Testing"
# Out:
# 'Matplotlib About To Start, Just Testing'

# %%
import pandas as pd
from main import *
data=pd.read_csv(loan_path)
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 from main import *
#       3 data=pd.read_csv(loan_path)
#       4 data
#
# ModuleNotFoundError: No module named 'main'

# %%
import matplotlib.pyplot as plt
