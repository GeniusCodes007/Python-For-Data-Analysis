# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/GENIUS DEXTER/Python For Data Analysis/csv_files/weatherAUS.csv")
data
# Out:
#              Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       5/18/2009        Hobart      5.1     14.3       0.0          1.8
# 1        7/3/2009    Launceston      1.1     14.5       0.4          NaN
# 2       2/18/2010   Williamtown     19.7     26.2       0.0          7.2
# 3        3/4/2010  PerthAirport     16.6     28.0       0.0          9.0
# 4        9/9/2010     GoldCoast     14.6     25.3       0.0          NaN
# ...           ...           ...      ...      ...       ...          ...
# 36876   6/14/2011         Perth     10.1     14.2       7.4          3.4
# 36877   9/24/2010  PerthAirport      6.3     26.0       0.0          5.0
# 36878    5/6/2011        Darwin     20.5     31.7       0.0          7.0
# 36879  10/12/2010         Perth      6.3     23.3       0.0          5.2
# 36880  12/22/2010     Nuriootpa      9.4     26.3       0.0          4.8
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0           8.9          NW           30.0        WSW  ...        47.0
# 1           NaN         SSW           50.0          E  ...        46.0
# 2           7.2         SSE           41.0        SSE  ...        50.0
# 3          11.3          SW           54.0        SSE  ...        41.0
# 4           NaN         NNW           43.0        WNW  ...        67.0
# ...         ...         ...            ...        ...  ...         ...
# 36876       0.0         NNE           46.0        NNE  ...        81.0
# 36877      10.6           W           37.0          N  ...        45.0
# 36878      11.1           E           37.0          E  ...        39.0
# 36879      11.6         SSW           39.0          E  ...        41.0
# 36880      12.2          SE           35.0        ENE  ...        28.0
#
#        Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0           1023.1       1022.2       1.0       1.0      9.1     13.3
# 1           1001.5       1002.4       NaN       NaN      1.3     13.7
# 2           1020.9       1021.9       6.0       4.0     22.7     24.4
# 3           1018.3       1014.9       6.0       1.0     20.0     26.1
# 4           1020.3       1015.0       NaN       NaN     22.2     22.6
# ...            ...          ...       ...       ...      ...      ...
# 36876       1016.2       1014.5       7.0       8.0     10.4     13.9
# 36877       1024.2       1021.5       1.0       1.0     18.4     23.5
# 36878       1012.6       1009.0       2.0       5.0     25.7     30.5
# 36879       1023.9       1019.9       0.0       1.0     16.4     20.9
# 36880       1017.5       1014.7       4.0       4.0     16.7     25.3
#
#        RainToday  RISK_MM  RainTomorrow
# 0             No      0.0            No
# 1             No      0.0            No
# 2             No      0.2            No
# 3             No      0.0            No
# 4             No      0.4            No
# ...          ...      ...           ...
# 36876        Yes      9.0           Yes
# 36877         No      0.0            No
# 36878         No      0.0            No
# 36879         No      0.0            No
# 36880         No      0.0            No
#
# [36881 rows x 24 columns]

# %%
# Convert Datetime string to proper date-time
pd.to_datetime(data.Date)
# Out:
# 0       2009-05-18
# 1       2009-07-03
# 2       2010-02-18
# 3       2010-03-04
# 4       2010-09-09
#            ...
# 36876   2011-06-14
# 36877   2010-09-24
# 36878   2011-05-06
# 36879   2010-10-12
# 36880   2010-12-22
# Name: Date, Length: 36881, dtype: datetime64[ns]

# %%
# Assign the new values to the 'Date' column, if not exists (create and assign)
data['Date']=pd.to_datetime(data.Date)

# %%
# Show month only
data.Date.dt.month
# Out:
# 0         5
# 1         7
# 2         2
# 3         3
# 4         9
#          ..
# 36876     6
# 36877     9
# 36878     5
# 36879    10
# 36880    12
# Name: Date, Length: 36881, dtype: int32

# %%
# Show year only
data.Date.dt.year
# Out:
# 0        2009
# 1        2009
# 2        2010
# 3        2010
# 4        2010
#          ...
# 36876    2011
# 36877    2010
# 36878    2011
# 36879    2010
# 36880    2010
# Name: Date, Length: 36881, dtype: int32

# %%
# Show day only
data.Date.dt.day
# Out:
# 0        18
# 1         3
# 2        18
# 3         4
# 4         9
#          ..
# 36876    14
# 36877    24
# 36878     6
# 36879    12
# 36880    22
# Name: Date, Length: 36881, dtype: int32

# %%
# Create new column 'Date Month'
data['Date Month']=data.Date.dt.month

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36881 entries, 0 to 36880
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           36881 non-null  datetime64[ns]
#  1   Location       36881 non-null  object
#  2   MinTemp        36543 non-null  float64
#  3   MaxTemp        36639 non-null  float64
#  4   Rainfall       36255 non-null  float64
#  5   Evaporation    24035 non-null  float64
#  6   Sunshine       23317 non-null  float64
#  7   WindGustDir    33513 non-null  object
#  8   WindGustSpeed  33520 non-null  float64
#  9   WindDir9am     34072 non-null  object
#  10  WindDir3pm     35919 non-null  object
#  11  WindSpeed9am   36219 non-null  float64
#  12  WindSpeed3pm   36235 non-null  float64
#  13  Humidity9am    36311 non-null  float64
#  14  Humidity3pm    36370 non-null  float64
#  15  Pressure9am    33309 non-null  float64
#  16  Pressure3pm    33329 non-null  float64
#  17  Cloud9am       24381 non-null  float64
#  18  Cloud3pm       23899 non-null  float64
#  19  Temp9am        36394 non-null  float64
#  20  Temp3pm        36437 non-null  float64
#  21  RainToday      36255 non-null  object
#  22  RISK_MM        36261 non-null  float64
#  23  RainTomorrow   36261 non-null  object
#  24  Date Month     36881 non-null  int32
# dtypes: datetime64[ns](1), float64(17), int32(1), object(6)
# memory usage: 6.9+ MB

# %%
data
# Out:
#             Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0     2009-05-18        Hobart      5.1     14.3       0.0          1.8
# 1     2009-07-03    Launceston      1.1     14.5       0.4          NaN
# 2     2010-02-18   Williamtown     19.7     26.2       0.0          7.2
# 3     2010-03-04  PerthAirport     16.6     28.0       0.0          9.0
# 4     2010-09-09     GoldCoast     14.6     25.3       0.0          NaN
# ...          ...           ...      ...      ...       ...          ...
# 36876 2011-06-14         Perth     10.1     14.2       7.4          3.4
# 36877 2010-09-24  PerthAirport      6.3     26.0       0.0          5.0
# 36878 2011-05-06        Darwin     20.5     31.7       0.0          7.0
# 36879 2010-10-12         Perth      6.3     23.3       0.0          5.2
# 36880 2010-12-22     Nuriootpa      9.4     26.3       0.0          4.8
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Pressure9am  \
# 0           8.9          NW           30.0        WSW  ...      1023.1
# 1           NaN         SSW           50.0          E  ...      1001.5
# 2           7.2         SSE           41.0        SSE  ...      1020.9
# 3          11.3          SW           54.0        SSE  ...      1018.3
# 4           NaN         NNW           43.0        WNW  ...      1020.3
# ...         ...         ...            ...        ...  ...         ...
# 36876       0.0         NNE           46.0        NNE  ...      1016.2
# 36877      10.6           W           37.0          N  ...      1024.2
# 36878      11.1           E           37.0          E  ...      1012.6
# 36879      11.6         SSW           39.0          E  ...      1023.9
# 36880      12.2          SE           35.0        ENE  ...      1017.5
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0           1022.2       1.0       1.0      9.1     13.3         No      0.0
# 1           1002.4       NaN       NaN      1.3     13.7         No      0.0
# 2           1021.9       6.0       4.0     22.7     24.4         No      0.2
# 3           1014.9       6.0       1.0     20.0     26.1         No      0.0
# 4           1015.0       NaN       NaN     22.2     22.6         No      0.4
# ...            ...       ...       ...      ...      ...        ...      ...
# 36876       1014.5       7.0       8.0     10.4     13.9        Yes      9.0
# 36877       1021.5       1.0       1.0     18.4     23.5         No      0.0
# 36878       1009.0       2.0       5.0     25.7     30.5         No      0.0
# 36879       1019.9       0.0       1.0     16.4     20.9         No      0.0
# 36880       1014.7       4.0       4.0     16.7     25.3         No      0.0
#
#        RainTomorrow  Date Month
# 0                No           5
# 1                No           7
# 2                No           2
# 3                No           3
# 4                No           9
# ...             ...         ...
# 36876           Yes           6
# 36877            No           9
# 36878            No           5
# 36879            No          10
# 36880            No          12
#
# [36881 rows x 25 columns]

# %%
data.sort_values(by='Date', inplace=True)

# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Using cached pandasql-0.7.3.tar.gz (26 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in C:\Users\GENIUS DEXTER\AppData\Roaming\Python\Python313\site-packages (from pandasql) (2.2.4)
# Requirement already satisfied: pandas in C:\Users\GENIUS DEXTER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandasql) (2.3.3)
# Requirement already satisfied: sqlalchemy in C:\Users\GENIUS DEXTER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandasql) (2.0.43)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\GENIUS DEXTER\AppData\Roaming\Python\Python313\site-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\GENIUS DEXTER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas->pandasql) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\GENIUS DEXTER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas->pandasql) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\GENIUS DEXTER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\GENIUS DEXTER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy->pandasql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\GENIUS DEXTER\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy->pandasql) (4.16.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (pyproject.toml): started
#   Building wheel for pandasql (pyproject.toml): finished with status 'done'
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26894 sha256=aecb5a6cd7c048e29ff0c97c447958fa99b095033f87f4f5253fdd25dac2f28c
#   Stored in directory: c:\users\genius dexter\appdata\local\pip\cache\wheels\b4\d0\8c\a6b366870bf041849cd96e03b71641e082f8d6456269b603b7
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
data.dropna(subset=['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19815 entries, 6314 to 19654
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           19815 non-null  datetime64[ns]
#  1   Location       19815 non-null  object
#  2   MinTemp        19799 non-null  float64
#  3   MaxTemp        19803 non-null  float64
#  4   Rainfall       19800 non-null  float64
#  5   Evaporation    19815 non-null  float64
#  6   Sunshine       19815 non-null  float64
#  7   WindGustDir    18095 non-null  object
#  8   WindGustSpeed  18097 non-null  float64
#  9   WindDir9am     19167 non-null  object
#  10  WindDir3pm     19685 non-null  object
#  11  WindSpeed9am   19752 non-null  float64
#  12  WindSpeed3pm   19771 non-null  float64
#  13  Humidity9am    19739 non-null  float64
#  14  Humidity3pm    19774 non-null  float64
#  15  Pressure9am    19763 non-null  float64
#  16  Pressure3pm    19770 non-null  float64
#  17  Cloud9am       19815 non-null  float64
#  18  Cloud3pm       19815 non-null  float64
#  19  Temp9am        19775 non-null  float64
#  20  Temp3pm        19797 non-null  float64
#  21  RainToday      19800 non-null  object
#  22  RISK_MM        19778 non-null  float64
#  23  RainTomorrow   19778 non-null  object
#  24  Date Month     19815 non-null  int32
# dtypes: datetime64[ns](1), float64(17), int32(1), object(6)
# memory usage: 3.9+ MB

# %%
data
# Out:
#             Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6314  2007-11-01       Canberra      8.0     24.3       0.0          3.4
# 23040 2007-11-02       Canberra     14.0     26.9       3.6          4.4
# 35788 2007-11-03       Canberra     13.7     23.4       3.6          5.8
# 21509 2007-11-04       Canberra     13.3     15.5      39.8          7.2
# 9670  2007-11-08       Canberra      8.3     17.0       0.0          5.6
# ...          ...            ...      ...      ...       ...          ...
# 26350 2012-01-30  NorfolkIsland     19.5     24.8       0.0          8.8
# 15515 2012-01-30   AliceSprings     23.6     41.0       0.0         13.8
# 2939  2012-01-30      Nuriootpa     17.0     24.2       0.4          4.4
# 31734 2012-01-30       Watsonia     21.0     31.0       2.4         10.8
# 19654 2012-01-30      Melbourne     22.3     32.5       2.8         10.8
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Pressure9am  \
# 6314        6.3          NW           30.0         SW  ...      1019.7
# 23040       9.7         ENE           39.0          E  ...      1012.4
# 35788       3.3          NW           85.0          N  ...      1009.5
# 21509       9.1          NW           54.0        WNW  ...      1005.5
# 9670        4.6           E           41.0         SE  ...      1026.2
# ...         ...         ...            ...        ...  ...         ...
# 26350      10.8           E           54.0          E  ...      1015.8
# 15515      12.8           S           67.0        SSW  ...      1001.7
# 2939        7.9         WSW           61.0          W  ...      1000.1
# 31734       6.9           W           63.0          N  ...       992.7
# 19654       6.9          SW           74.0          N  ...       992.4
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 6314        1015.0       7.0       7.0     14.4     23.6         No      3.6
# 23040       1008.4       5.0       3.0     17.5     25.7        Yes      3.6
# 35788       1007.2       8.0       7.0     15.4     20.2        Yes     39.8
# 21509       1007.0       2.0       7.0     13.5     14.1        Yes      2.8
# 9670        1024.2       6.0       7.0     12.1     15.5         No      0.0
# ...            ...       ...       ...      ...      ...        ...      ...
# 26350       1014.3       2.0       6.0     22.7     22.8         No      0.0
# 15515        999.8       1.0       5.0     31.4     38.8         No      0.0
# 2939        1003.6       8.0       6.0     17.2     22.2         No      0.0
# 31734        990.9       7.0       3.0     23.5     29.7        Yes      7.4
# 19654        990.6       7.0       5.0     23.7     29.5        Yes      3.4
#
#        RainTomorrow  Date Month
# 6314            Yes          11
# 23040           Yes          11
# 35788           Yes          11
# 21509           Yes          11
# 9670             No          11
# ...             ...         ...
# 26350            No           1
# 15515            No           1
# 2939             No           1
# 31734           Yes           1
# 19654           Yes           1
#
# [19815 rows x 25 columns]
