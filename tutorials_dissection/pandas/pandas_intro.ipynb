# %%
from datasets import load_dataset
dataset=load_dataset('lukebarousse/data_jobs')
# Out:
# '[Errno 11001] getaddrinfo failed' thrown while requesting HEAD https://huggingface.co/datasets/lukebarousse/data_jobs/resolve/ed776e5a0a8c40ea9d5efbd800772ae52e140f3e/data_jobs.py
# Retrying in 1s [Retry 1/5].
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 from datasets import load_dataset
# ----> 2 dataset=load_dataset('lukebarousse/data_jobs')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\datasets\load.py:1698, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1693 verification_mode = VerificationMode(
# ...

# %%
dataset['train']

# %%
df=dataset['train'].to_pandas()

# %%
import pandas as pd

#df = pd.read_csv("hf://datasets/lukebarousse/data_jobs/data_jobs.csv")

# %%
data['train']

# %%
import pandas as pd
data=pd.read_csv('C:/Users/GENIUS DEXTER/Python For Data Analysis/csv_files/ToyotaCorolla.csv')

data
# Out:
#       Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500   23  46986   Diesel   90         1          0  2000      3
# 1     13750   23  72937   Diesel   90         1          0  2000      3
# 2     13950   24  41711   Diesel   90         1          0  2000      3
# 3     14950   26  48000   Diesel   90         0          0  2000      3
# 4     13750   30  38500   Diesel   90         0          0  2000      3
# ...     ...  ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   69  20544   Petrol   86         1          0  1300      3
# 1432  10845   72  19000   Petrol   86         0          0  1300      3
# 1433   8500   71  17016   Petrol   86         0          0  1300      3
# 1434   7250   70  16916   Petrol   86         1          0  1300      3
# 1435   6950   76      1   Petrol  110         0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# ...

# %%
# First n rows, 

data.head(7)
# Out:
#    Price  Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500   23  46986   Diesel  90         1          0  2000      3    1165
# 1  13750   23  72937   Diesel  90         1          0  2000      3    1165
# 2  13950   24  41711   Diesel  90         1          0  2000      3    1165
# 3  14950   26  48000   Diesel  90         0          0  2000      3    1165
# 4  13750   30  38500   Diesel  90         0          0  2000      3    1170
# 5  12950   32  61000   Diesel  90         0          0  2000      3    1170
# 6  16900   27  94612   Diesel  90         1          0  2000      3    1245

# %%
#by default n=5
data.head()
# Out:
#    Price  Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500   23  46986   Diesel  90         1          0  2000      3    1165
# 1  13750   23  72937   Diesel  90         1          0  2000      3    1165
# 2  13950   24  41711   Diesel  90         1          0  2000      3    1165
# 3  14950   26  48000   Diesel  90         0          0  2000      3    1165
# 4  13750   30  38500   Diesel  90         0          0  2000      3    1170

# %%
# Last n rows
data.tail(9)
# Out:
#       Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 1427   8950   71  29000   Petrol   86         1          1  1300      3
# 1428   8450   72  26000   Petrol   86         0          0  1300      3
# 1429   8950   78  24000   Petrol   86         1          1  1300      5
# 1430   8450   80  23000   Petrol   86         0          0  1300      3
# 1431   7500   69  20544   Petrol   86         1          0  1300      3
# 1432  10845   72  19000   Petrol   86         0          0  1300      3
# 1433   8500   71  17016   Petrol   86         0          0  1300      3
# 1434   7250   70  16916   Petrol   86         1          0  1300      3
# 1435   6950   76      1   Petrol  110         0          0  1600      5
#
#       Weight
# 1427    1045
# 1428    1015
# 1429    1065
# 1430    1015
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114

# %%
# by default n=5
data.tail()
# Out:
#       Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 1431   7500   69  20544   Petrol   86         1          0  1300      3
# 1432  10845   72  19000   Petrol   86         0          0  1300      3
# 1433   8500   71  17016   Petrol   86         0          0  1300      3
# 1434   7250   70  16916   Petrol   86         1          0  1300      3
# 1435   6950   76      1   Petrol  110         0          0  1600      5
#
#       Weight
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114

# %%
# data type
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Get a column
"""
DataFrame objects are usually stored as dictionaries
"""
data['KM']
# Out:
# 0       46986
# 1       72937
# 2       41711
# 3       48000
# 4       38500
#         ...
# 1431    20544
# 1432    19000
# 1433    17016
# 1434    16916
# 1435        1
# Name: KM, Length: 1436, dtype: int64

# %%
# Get a particular line
data.iloc[34:120]
# Out:
#      Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  Weight
# 34   15500   22  41000   Petrol   97         1          0  1400      3    1100
# 35   15750   26  43000   Petrol   97         0          0  1400      3    1100
# 36   15950   25  25000   Petrol   97         0          0  1400      3    1100
# 37   14950   23  10000   Petrol   97         1          0  1400      3    1100
# 38   15750   32  25329   Petrol   97         1          0  1400      3    1100
# ..     ...  ...    ...      ...  ...       ...        ...   ...    ...     ...
# 115  24990    8   6000   Diesel   90         1          0  2000      5    1280
# 116  21950    8  10841   Diesel   90         1          0  2000      5    1270
# 117  17900    7      1   Petrol  110         1          0  1600      3    1105
# 118  19250   20  63000   Diesel   90         1          0  2000      5    1255
# 119  22250   17  57313   Diesel  110         1          0  2000      5    1275
#
# [86 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   MetColor   1436 non-null   int64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 112.3+ KB

# %%
len(data)
# Out:
# 1436

# %%
data.shape
# Out:
# (1436, 10)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1436, step=1)

# %%
data.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
data.count()
# Out:
# Price        1436
# Age          1436
# KM           1436
# FuelType     1436
# HP           1436
# MetColor     1436
# Automatic    1436
# CC           1436
# Doors        1436
# Weight       1436
# dtype: int64

# %%
data.describe()
# Out:
#               Price          Age             KM           HP     MetColor  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.674791
# std     3626.964585    18.599988   37506.448872    14.981080     0.468616
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     1.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     1.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#          Automatic           CC        Doors      Weight
# count  1436.000000  1436.000000  1436.000000  1436.00000
# mean      0.055710  1566.827994     4.033426  1072.45961
# std       0.229441   187.182436     0.952677    52.64112
# min       0.000000  1300.000000     2.000000  1000.00000
# ...

# %%
data.Price.unique()
# Out:
# array([13500, 13750, 13950, 14950, 12950, 16900, 18600, 21500, 20950,
#        19950, 19600, 22500, 22000, 22750, 17950, 16750, 16950, 15950,
#        16250, 17495, 15750, 15500, 14750, 19000, 15800, 21950, 20500,
#        13250, 15250, 18950, 15999, 16500, 18750, 22250, 12995, 18450,
#        16895, 14900, 17250, 15450, 16650, 17450, 16450, 18900, 18990,
#        18500, 19450, 18800, 32500, 31000, 31275, 24950, 22950, 24990,
#        17900, 19250, 16350, 21750, 15850, 23000, 19900, 23950, 24500,
#        17200, 19500, 16868, 19750, 20750, 17650, 17795, 18245, 23750,
#        18700, 21125,  6950,  9500, 11950,  7750,  4350,  4750, 11750,
#        11900,  9950, 11495, 11250, 10500, 10450, 11500, 12500, 10950,
#        11450, 11790, 12450, 11690, 12750, 11925, 12900, 11650, 10850,
#         9940, 13450, 12495, 12000, 11480, 14990, 12850, 11700, 11895,
#        13875, 12295, 13995,  9900, 11990, 10750, 11695, 11000, 12400,
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   MetColor   1436 non-null   int64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 112.3+ KB

# %%
data[(data.KM>40000) & (data.Weight>1200)]
# Out:
#      Price  Age      KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 6    16900   27   94612   Diesel   90         1          0  2000      3
# 7    18600   30   75889   Diesel   90         1          0  2000      3
# 43   16950   27  110404   Diesel   90         0          0  2000      5
# 44   16950   22  100250   Diesel   90         0          0  2000      5
# 45   19000   23   84000   Diesel   90         0          0  2000      5
# 46   17950   27   79375   Diesel   90         1          0  2000      5
# 48   17950   22   72215   Diesel   90         1          0  2000      5
# 50   17950   22   62636   Diesel   90         1          0  2000      5
# 87   17950   20   66966   Diesel   90         1          0  2000      3
# 89   21950   19   50005   Diesel  110         1          0  2000      3
# 118  19250   20   63000   Diesel   90         1          0  2000      5
# 119  22250   17   57313   Diesel  110         1          0  2000      5
# ...
