# %% [markdown]
# <a href="https://colab.research.google.com/github/GeniusCodes007/Python-For-Data-Analysis/blob/main/matplotlib_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Matplotlib Loading!!!"
# Out:
# 'Matplotlib Loading!!!'

# %%
# !git add --all
# Out:
# fatal: not a git repository (or any of the parent directories): .git
